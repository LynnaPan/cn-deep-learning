# %% [markdown]
# # 图像分类
#
# 在此项目中，你将对 [CIFAR-10 数据集](https://www.cs.toronto.edu/~kriz/cifar.html) 中的图片进行分类。该数据集包含飞机、猫狗和其他物体。你需要预处理这些图片，然后用所有样本训练一个卷积神经网络。图片需要标准化（normalized），标签需要采用 one-hot 编码。你需要应用所学的知识构建卷积的、最大池化（max pooling）、丢弃（dropout）和完全连接（fully connected）的层。最后，你需要在样本图片上看到神经网络的预测结果。
#
#
# ## 获取数据
#
# 请运行以下单元，以下载 [CIFAR-10 数据集（Python版）](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz)。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## 探索数据
#
# 该数据集分成了几部分／批次（batches），以免你的机器在计算时内存不足。CIFAR-10 数据集包含 5 个部分，名称分别为 `data_batch_1`、`data_batch_2`，以此类推。每个部分都包含以下某个类别的标签和图片：
#
# * 飞机
# * 汽车
# * 鸟类
# * 猫
# * 鹿
# * 狗
# * 青蛙
# * 马
# * 船只
# * 卡车
#
# 了解数据集也是对数据进行预测的必经步骤。你可以通过更改 `batch_id` 和 `sample_id` 探索下面的代码单元。`batch_id` 是数据集一个部分的 ID（1 到 5）。`sample_id` 是该部分中图片和标签对（label pair）的 ID。
#
# 问问你自己：“可能的标签有哪些？”、“图片数据的值范围是多少？”、“标签是按顺序排列，还是随机排列的？”。思考类似的问题，有助于你预处理数据，并使预测结果更准确。

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## 实现预处理函数
#
# ### 标准化
#
# 在下面的单元中，实现 `normalize` 函数，传入图片数据 `x`，并返回标准化 Numpy 数组。值应该在 0 到 1 的范围内（含 0 和 1）。返回对象应该和 `x` 的形状一样。

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    normalized = x/256
    return normalized


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot 编码
#
# 和之前的代码单元一样，你将为预处理实现一个函数。这次，你将实现 `one_hot_encode` 函数。输入，也就是 `x`，是一个标签列表。实现该函数，以返回为 one_hot 编码的 Numpy 数组的标签列表。标签的可能值为 0 到 9。每次调用 `one_hot_encode` 时，对于每个值，one_hot 编码函数应该返回相同的编码。确保将编码映射保存到该函数外面。
#
# 提示：不要重复发明轮子。

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    targets = np.array(x).reshape(-1)
    one_hot_targets = np.eye(10)[targets]
    return one_hot_targets



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### 随机化数据
#
# 之前探索数据时，你已经了解到，样本的顺序是随机的。再随机化一次也不会有什么关系，但是对于这个数据集没有必要。

# %% [markdown]
# ## 预处理所有数据并保存
#
# 运行下方的代码单元，将预处理所有 CIFAR-10 数据，并保存到文件中。下面的代码还使用了 10% 的训练数据，用来验证。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # 检查点
#
# 这是你的第一个检查点。如果你什么时候决定再回到该记事本，或需要重新启动该记事本，你可以从这里开始。预处理的数据已保存到本地。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## 构建网络
#
# 对于该神经网络，你需要将每层都构建为一个函数。你看到的大部分代码都位于函数外面。要更全面地测试你的代码，我们需要你将每层放入一个函数中。这样使我们能够提供更好的反馈，并使用我们的统一测试检测简单的错误，然后再提交项目。
#
# >**注意**：如果你觉得每周很难抽出足够的时间学习这门课程，我们为此项目提供了一个小捷径。对于接下来的几个问题，你可以使用 [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) 或 [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) 程序包中的类来构建每个层级，但是“卷积和最大池化层级”部分的层级除外。TF Layers 和 Keras 及 TFLearn 层级类似，因此很容易学会。
#
# >但是，如果你想充分利用这门课程，请尝试自己解决所有问题，不使用 TF Layers 程序包中的任何类。你依然可以使用其他程序包中的类，这些类和你在 TF Layers 中的类名称是一样的！例如，你可以使用 TF Neural Network 版本的 `conv2d` 类 [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d)，而不是 TF Layers 版本的 `conv2d` 类 [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d)。
#
# 我们开始吧！
#
#
# ### 输入
#
# 神经网络需要读取图片数据、one-hot 编码标签和丢弃保留概率（dropout keep probability）。请实现以下函数：
#
# * 实现 `neural_net_image_input`
#  * 返回 [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * 使用 `image_shape` 设置形状，部分大小设为 `None`
#  * 使用 [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) 中的 TensorFlow `name` 参数对 TensorFlow 占位符 "x" 命名
# * 实现 `neural_net_label_input`
#  * 返回 [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * 使用 `n_classes` 设置形状，部分大小设为 `None`
#  * 使用 [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) 中的 TensorFlow `name` 参数对 TensorFlow 占位符 "y" 命名
# * 实现 `neural_net_keep_prob_input`
#  * 返回 [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)，用于丢弃保留概率
#  * 使用 [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) 中的 TensorFlow `name` 参数对 TensorFlow 占位符 "keep_prob" 命名
#
# 这些名称将在项目结束时，用于加载保存的模型。
#
# 注意：TensorFlow 中的 `None` 表示形状可以是动态大小。

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape=[None, image_shape[0], image_shape[1], image_shape[2]], name='x')

def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape=[None, n_classes], name='y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, name='keep_prob')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### 卷积和最大池化层
#
# 卷积层级适合处理图片。对于此代码单元，你应该实现函数 `conv2d_maxpool` 以便应用卷积然后进行最大池化：
#
# * 使用 `conv_ksize`、`conv_num_outputs` 和 `x_tensor` 的形状创建权重（weight）和偏置（bias）。
# * 使用权重和 `conv_strides` 对 `x_tensor` 应用卷积。
#  * 建议使用我们建议的间距（padding），当然也可以使用任何其他间距。
# * 添加偏置
# * 向卷积中添加非线性激活（nonlinear activation）
# * 使用 `pool_ksize` 和 `pool_strides` 应用最大池化
#  * 建议使用我们建议的间距（padding），当然也可以使用任何其他间距。
#
# **注意**：对于**此层**，**请勿使用** [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) 或 [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers)，但是仍然可以使用 TensorFlow 的 [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) 包。对于所有**其他层**，你依然可以使用快捷方法。

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    weight = tf.Variable(tf.truncated_normal([conv_ksize[0], 
                                              conv_ksize[1], 
                                              int(x_tensor.get_shape()[3]), 
                                              conv_num_outputs]))
    bias = tf.Variable(tf.zeros(conv_num_outputs))
    conv_layer = tf.nn.conv2d(x_tensor, weight, 
                              [1, conv_strides[0], 
                               conv_strides[1],1], 
                              padding='SAME')
    conv_layer = tf.nn.bias_add(conv_layer, bias)
    conv_layer = tf.nn.relu(conv_layer)
    conv_layer = tf.nn.max_pool(
    conv_layer,
    ksize=[1, pool_ksize[0], pool_ksize[1],1],
    strides=[1, pool_strides[0], pool_strides[1],1],
    padding='SAME')
    return conv_layer 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### 扁平化层
#
# 实现 `flatten` 函数，将 `x_tensor` 的维度从四维张量（4-D tensor）变成二维张量。输出应该是形状（*部分大小（Batch Size）*，*扁平化图片大小（Flattened Image Size）*）。快捷方法：对于此层，你可以使用 [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) 或 [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) 包中的类。如果你想要更大挑战，可以仅使用其他 TensorFlow 程序包。

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    input = int(x_tensor.get_shape()[1])*int(x_tensor.get_shape()[2])*int(x_tensor.get_shape()[3])
    x_flatten = tf.reshape(x_tensor, [-1, input])
    return x_flatten


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### 全连接层
#
# 实现 `fully_conn` 函数，以向 `x_tensor` 应用完全连接的层级，形状为（*部分大小（Batch Size）*，*num_outputs*）。快捷方法：对于此层，你可以使用 [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) 或 [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) 包中的类。如果你想要更大挑战，可以仅使用其他 TensorFlow 程序包。

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    return tf.contrib.layers.fully_connected(x_tensor, num_outputs)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### 输出层
#
# 实现 `output` 函数，向 x_tensor 应用完全连接的层级，形状为（*部分大小（Batch Size）*，*num_outputs*）。快捷方法：对于此层，你可以使用 [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) 或 [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) 包中的类。如果你想要更大挑战，可以仅使用其他 TensorFlow 程序包。
#
# **注意**：该层级不应应用 Activation、softmax 或交叉熵（cross entropy）。

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    input_shape = int(x_tensor.shape[1])
    weight = tf.Variable(tf.random_normal([input_shape, num_outputs]))
    bias = tf.Variable(tf.random_normal([num_outputs]))
    out = tf.add(tf.matmul(x_tensor, weight), bias)
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### 创建卷积模型
#
# 实现函数 `conv_net`， 创建卷积神经网络模型。该函数传入一批图片 `x`，并输出对数（logits）。使用你在上方创建的层创建此模型：
#
# * 应用 1、2 或 3 个卷积和最大池化层（Convolution and Max Pool layers）
# * 应用一个扁平层（Flatten Layer）
# * 应用 1、2 或 3 个完全连接层（Fully Connected Layers）
# * 应用一个输出层（Output Layer）
# * 返回输出
# * 使用 `keep_prob` 向模型中的一个或多个层应用 [TensorFlow 的 Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout)

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    layer1 = conv2d_maxpool(x, 16, (2, 2), (2,2), (2,2), (2,2))
    #layer2 = conv2d_maxpool(layer1, 128, (2,2), (2,2), (2,2), (2,2))
    #layer2 = tf.nn.dropout(layer2, keep_prob)
    #layer3 = conv2d_maxpool(layer2, 256, (2,2), (2,2), (2,2), (2,2))
    
    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    flatten_layer = flatten(layer1)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    fc1 = fully_conn(flatten_layer, 512)
    fc2 = fully_conn(fc1, 1024)
    fc3 = fully_conn(fc2, 2048)
    fc3 = tf.nn.dropout(fc3, keep_prob)
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    output_layer = output(fc3, 10)
    
    # TODO: return output
    return output_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## 训练神经网络
#
# ### 单次优化
#
# 实现函数 `train_neural_network` 以进行单次优化（single optimization）。该优化应该使用 `optimizer` 优化 `session`，其中 `feed_dict` 具有以下参数：
#
# * `x` 表示图片输入
# * `y` 表示标签
# * `keep_prob` 表示丢弃的保留率
#
# 每个部分都会调用该函数，所以 `tf.global_variables_initializer()` 已经被调用。
#
# 注意：不需要返回任何内容。该函数只是用来优化神经网络。

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    train_feed_dict = {
        x: feature_batch,
        y: label_batch,
        keep_prob: keep_probability}
    session.run(optimizer, feed_dict=train_feed_dict)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### 显示数据
#
# 实现函数 `print_stats` 以输出损失和验证准确率。使用全局变量 `valid_features` 和 `valid_labels` 计算验证准确率。使用保留率 `1.0` 计算损失和验证准确率（loss and validation accuracy）。

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    current_cost = session.run(
        cost,
        feed_dict={x: feature_batch, y: label_batch, keep_prob: 1.0})
    valid_accuracy = session.run(
        accuracy,
        feed_dict={x: valid_features, y: valid_labels, keep_prob: 1.0})
    print('Cost: {:<8.3} Valid Accuracy: {:<5.3}'.format(
        current_cost,
        valid_accuracy))

# %% [markdown]
# ### 超参数
#
# 调试以下超参数：
# * 设置 `epochs` 表示神经网络停止学习或开始过拟合的迭代次数
# * 设置 `batch_size`，表示机器内存允许的部分最大体积。大部分人设为以下常见内存大小：
#
#  * 64
#  * 128
#  * 256
#  * ...
# * 设置 `keep_probability` 表示使用丢弃时保留节点的概率

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 512
keep_probability = 0.75

# %% [markdown]
# ### 在单个 CIFAR-10 部分上训练
#
# 我们先用单个部分，而不是用所有的 CIFAR-10 批次训练神经网络。这样可以节省时间，并对模型进行迭代，以提高准确率。最终验证准确率达到 50% 或以上之后，在下一部分对所有数据运行模型。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Cost: 2.13     Valid Accuracy: 0.215
# Epoch  2, CIFAR-10 Batch 1:  Cost: 1.97     Valid Accuracy: 0.294
# Epoch  3, CIFAR-10 Batch 1:  Cost: 1.75     Valid Accuracy: 0.338
# Epoch  4, CIFAR-10 Batch 1:  Cost: 1.56     Valid Accuracy: 0.372
# Epoch  5, CIFAR-10 Batch 1:  Cost: 1.39     Valid Accuracy: 0.39
# Epoch  6, CIFAR-10 Batch 1:  Cost: 1.23     Valid Accuracy: 0.407
# Epoch  7, CIFAR-10 Batch 1:  Cost: 1.09     Valid Accuracy: 0.424
# Epoch  8, CIFAR-10 Batch 1:  Cost: 0.982    Valid Accuracy: 0.449
# Epoch  9, CIFAR-10 Batch 1:  Cost: 0.885    Valid Accuracy: 0.443
# Epoch 10, CIFAR-10 Batch 1:  Cost: 0.779    Valid Accuracy: 0.455
# Epoch 11, CIFAR-10 Batch 1:  Cost: 0.668    Valid Accuracy: 0.46
# Epoch 12, CIFAR-10 Batch 1:  Cost: 0.618    Valid Accuracy: 0.469
# Epoch 13, CIFAR-10 Batch 1:  Cost: 0.559    Valid Accuracy: 0.463
# Epoch 14, CIFAR-10 Batch 1:  Cost: 0.518    Valid Accuracy: 0.464
# Epoch 15, CIFAR-10 Batch 1:  Cost: 0.445    Valid Accuracy: 0.474
# Epoch 16, CIFAR-10 Batch 1:  Cost: 0.453    Valid Accuracy: 0.456
# Epoch 17, CIFAR-10 Batch 1:  Cost: 0.414    Valid Accuracy: 0.466
# Epoch 18, CIFAR-10 Batch 1:  Cost: 0.488    Valid Accuracy: 0.466
# Epoch 19, CIFAR-10 Batch 1:  Cost: 0.433    Valid Accuracy: 0.445
# Epoch 20, CIFAR-10 Batch 1:  Cost: 0.332    Valid Accuracy: 0.463
# Epoch 21, CIFAR-10 Batch 1:  Cost: 0.289    Valid Accuracy: 0.455
# Epoch 22, CIFAR-10 Batch 1:  Cost: 0.334    Valid Accuracy: 0.461
# Epoch 23, CIFAR-10 Batch 1:  Cost: 0.249    Valid Accuracy: 0.456
# Epoch 24, CIFAR-10 Batch 1:  Cost: 0.244    Valid Accuracy: 0.471
# Epoch 25, CIFAR-10 Batch 1:  Cost: 0.241    Valid Accuracy: 0.465
# Epoch 26, CIFAR-10 Batch 1:  Cost: 0.239    Valid Accuracy: 0.476
# Epoch 27, CIFAR-10 Batch 1:  Cost: 0.186    Valid Accuracy: 0.48
# Epoch 28, CIFAR-10 Batch 1:  Cost: 0.177    Valid Accuracy: 0.468
# Epoch 29, CIFAR-10 Batch 1:  Cost: 0.146    Valid Accuracy: 0.473
# Epoch 30, CIFAR-10 Batch 1:  Cost: 0.13     Valid Accuracy: 0.485
# Epoch 31, CIFAR-10 Batch 1:  Cost: 0.123    Valid Accuracy: 0.483
# Epoch 32, CIFAR-10 Batch 1:  Cost: 0.12     Valid Accuracy: 0.485
# Epoch 33, CIFAR-10 Batch 1:  Cost: 0.11     Valid Accuracy: 0.475
# Epoch 34, CIFAR-10 Batch 1:  Cost: 0.115    Valid Accuracy: 0.477
# Epoch 35, CIFAR-10 Batch 1:  Cost: 0.128    Valid Accuracy: 0.472
# Epoch 36, CIFAR-10 Batch 1:  Cost: 0.111    Valid Accuracy: 0.47
# Epoch 37, CIFAR-10 Batch 1:  Cost: 0.0932   Valid Accuracy: 0.483
# Epoch 38, CIFAR-10 Batch 1:  Cost: 0.0678   Valid Accuracy: 0.486
# Epoch 39, CIFAR-10 Batch 1:  Cost: 0.0585   Valid Accuracy: 0.478
# Epoch 40, CIFAR-10 Batch 1:  Cost: 0.0712   Valid Accuracy: 0.478
# Epoch 41, CIFAR-10 Batch 1:  Cost: 0.0944   Valid Accuracy: 0.468
# Epoch 42, CIFAR-10 Batch 1:  Cost: 0.0632   Valid Accuracy: 0.481
# Epoch 43, CIFAR-10 Batch 1:  Cost: 0.0572   Valid Accuracy: 0.49
# Epoch 44, CIFAR-10 Batch 1:  Cost: 0.0449   Valid Accuracy: 0.482
# Epoch 45, CIFAR-10 Batch 1:  Cost: 0.0544   Valid Accuracy: 0.466
# Epoch 46, CIFAR-10 Batch 1:  Cost: 0.0498   Valid Accuracy: 0.463
# Epoch 47, CIFAR-10 Batch 1:  Cost: 0.0763   Valid Accuracy: 0.458
# Epoch 48, CIFAR-10 Batch 1:  Cost: 0.0626   Valid Accuracy: 0.465
# Epoch 49, CIFAR-10 Batch 1:  Cost: 0.0617   Valid Accuracy: 0.47
# Epoch 50, CIFAR-10 Batch 1:  Cost: 0.0639   Valid Accuracy: 0.469
# Epoch 51, CIFAR-10 Batch 1:  Cost: 0.0399   Valid Accuracy: 0.48
# Epoch 52, CIFAR-10 Batch 1:  Cost: 0.0548   Valid Accuracy: 0.474
# Epoch 53, CIFAR-10 Batch 1:  Cost: 0.0634   Valid Accuracy: 0.469
# Epoch 54, CIFAR-10 Batch 1:  Cost: 0.0562   Valid Accuracy: 0.468
# Epoch 55, CIFAR-10 Batch 1:  Cost: 0.0535   Valid Accuracy: 0.47
# Epoch 56, CIFAR-10 Batch 1:  Cost: 0.0402   Valid Accuracy: 0.47
# Epoch 57, CIFAR-10 Batch 1:  Cost: 0.0223   Valid Accuracy: 0.491
# Epoch 58, CIFAR-10 Batch 1:  Cost: 0.0148   Valid Accuracy: 0.496
# Epoch 59, CIFAR-10 Batch 1:  Cost: 0.00835  Valid Accuracy: 0.49
# Epoch 60, CIFAR-10 Batch 1:  Cost: 0.00543  Valid Accuracy: 0.496
# Epoch 61, CIFAR-10 Batch 1:  Cost: 0.00385  Valid Accuracy: 0.502
# Epoch 62, CIFAR-10 Batch 1:  Cost: 0.00396  Valid Accuracy: 0.508
# Epoch 63, CIFAR-10 Batch 1:  Cost: 0.00349  Valid Accuracy: 0.501
# Epoch 64, CIFAR-10 Batch 1:  Cost: 0.00208  Valid Accuracy: 0.508
# Epoch 65, CIFAR-10 Batch 1:  Cost: 0.00314  Valid Accuracy: 0.506
# Epoch 66, CIFAR-10 Batch 1:  Cost: 0.00247  Valid Accuracy: 0.506
# Epoch 67, CIFAR-10 Batch 1:  Cost: 0.00254  Valid Accuracy: 0.501
# Epoch 68, CIFAR-10 Batch 1:  Cost: 0.00151  Valid Accuracy: 0.502
# Epoch 69, CIFAR-10 Batch 1:  Cost: 0.00221  Valid Accuracy: 0.5
# Epoch 70, CIFAR-10 Batch 1:  Cost: 0.000777 Valid Accuracy: 0.506
# Epoch 71, CIFAR-10 Batch 1:  Cost: 0.000705 Valid Accuracy: 0.508
# Epoch 72, CIFAR-10 Batch 1:  Cost: 0.000554 Valid Accuracy: 0.509
# Epoch 73, CIFAR-10 Batch 1:  Cost: 0.000422 Valid Accuracy: 0.507
# Epoch 74, CIFAR-10 Batch 1:  Cost: 0.000454 Valid Accuracy: 0.51
# Epoch 75, CIFAR-10 Batch 1:  Cost: 0.000359 Valid Accuracy: 0.51
# Epoch 76, CIFAR-10 Batch 1:  Cost: 0.000368 Valid Accuracy: 0.509
# Epoch 77, CIFAR-10 Batch 1:  Cost: 0.000336 Valid Accuracy: 0.508
# Epoch 78, CIFAR-10 Batch 1:  Cost: 0.000307 Valid Accuracy: 0.51
# Epoch 79, CIFAR-10 Batch 1:  Cost: 0.00029  Valid Accuracy: 0.509
# Epoch 80, CIFAR-10 Batch 1:  Cost: 0.000269 Valid Accuracy: 0.51
# Epoch 81, CIFAR-10 Batch 1:  Cost: 0.000273 Valid Accuracy: 0.509
# Epoch 82, CIFAR-10 Batch 1:  Cost: 0.000256 Valid Accuracy: 0.507
# Epoch 83, CIFAR-10 Batch 1:  Cost: 0.000239 Valid Accuracy: 0.509
# Epoch 84, CIFAR-10 Batch 1:  Cost: 0.00023  Valid Accuracy: 0.507
# Epoch 85, CIFAR-10 Batch 1:  Cost: 0.00024  Valid Accuracy: 0.509
# Epoch 86, CIFAR-10 Batch 1:  Cost: 0.000205 Valid Accuracy: 0.508
# Epoch 87, CIFAR-10 Batch 1:  Cost: 0.000206 Valid Accuracy: 0.508
# Epoch 88, CIFAR-10 Batch 1:  Cost: 0.000186 Valid Accuracy: 0.511
# Epoch 89, CIFAR-10 Batch 1:  Cost: 0.000175 Valid Accuracy: 0.51
# Epoch 90, CIFAR-10 Batch 1:  Cost: 0.000177 Valid Accuracy: 0.511
# Epoch 91, CIFAR-10 Batch 1:  Cost: 0.000171 Valid Accuracy: 0.51
# Epoch 92, CIFAR-10 Batch 1:  Cost: 0.000161 Valid Accuracy: 0.509
# Epoch 93, CIFAR-10 Batch 1:  Cost: 0.000164 Valid Accuracy: 0.51
# Epoch 94, CIFAR-10 Batch 1:  Cost: 0.000159 Valid Accuracy: 0.51
# Epoch 95, CIFAR-10 Batch 1:  Cost: 0.00015  Valid Accuracy: 0.51
# Epoch 96, CIFAR-10 Batch 1:  Cost: 0.000148 Valid Accuracy: 0.511
# Epoch 97, CIFAR-10 Batch 1:  Cost: 0.000141 Valid Accuracy: 0.509
# Epoch 98, CIFAR-10 Batch 1:  Cost: 0.000133 Valid Accuracy: 0.511
# Epoch 99, CIFAR-10 Batch 1:  Cost: 0.000127 Valid Accuracy: 0.509
# Epoch 100, CIFAR-10 Batch 1:  Cost: 0.000118 Valid Accuracy: 0.509

# %% [markdown]
# ### 完全训练模型
#
# 现在，单个 CIFAR-10 部分的准确率已经不错了，试试所有五个部分吧。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Cost: 2.37     Valid Accuracy: 0.182
# Epoch  1, CIFAR-10 Batch 2:  Cost: 1.97     Valid Accuracy: 0.284
# Epoch  1, CIFAR-10 Batch 3:  Cost: 1.8      Valid Accuracy: 0.323
# Epoch  1, CIFAR-10 Batch 4:  Cost: 1.71     Valid Accuracy: 0.348
# Epoch  1, CIFAR-10 Batch 5:  Cost: 1.71     Valid Accuracy: 0.372
# Epoch  2, CIFAR-10 Batch 1:  Cost: 1.69     Valid Accuracy: 0.391
# Epoch  2, CIFAR-10 Batch 2:  Cost: 1.56     Valid Accuracy: 0.403
# Epoch  2, CIFAR-10 Batch 3:  Cost: 1.47     Valid Accuracy: 0.415
# Epoch  2, CIFAR-10 Batch 4:  Cost: 1.39     Valid Accuracy: 0.427
# Epoch  2, CIFAR-10 Batch 5:  Cost: 1.43     Valid Accuracy: 0.445
# Epoch  3, CIFAR-10 Batch 1:  Cost: 1.47     Valid Accuracy: 0.457
# Epoch  3, CIFAR-10 Batch 2:  Cost: 1.33     Valid Accuracy: 0.457
# Epoch  3, CIFAR-10 Batch 3:  Cost: 1.25     Valid Accuracy: 0.47
# Epoch  3, CIFAR-10 Batch 4:  Cost: 1.24     Valid Accuracy: 0.476
# Epoch  3, CIFAR-10 Batch 5:  Cost: 1.25     Valid Accuracy: 0.496
# Epoch  4, CIFAR-10 Batch 1:  Cost: 1.25     Valid Accuracy: 0.499
# Epoch  4, CIFAR-10 Batch 2:  Cost: 1.18     Valid Accuracy: 0.497
# Epoch  4, CIFAR-10 Batch 3:  Cost: 1.08     Valid Accuracy: 0.521
# Epoch  4, CIFAR-10 Batch 4:  Cost: 1.05     Valid Accuracy: 0.511
# Epoch  4, CIFAR-10 Batch 5:  Cost: 1.11     Valid Accuracy: 0.521
# Epoch  5, CIFAR-10 Batch 1:  Cost: 1.12     Valid Accuracy: 0.519
# Epoch  5, CIFAR-10 Batch 2:  Cost: 1.05     Valid Accuracy: 0.512
# Epoch  5, CIFAR-10 Batch 3:  Cost: 1.04     Valid Accuracy: 0.513
# Epoch  5, CIFAR-10 Batch 4:  Cost: 0.926    Valid Accuracy: 0.531
# Epoch  5, CIFAR-10 Batch 5:  Cost: 1.05     Valid Accuracy: 0.528
# Epoch  6, CIFAR-10 Batch 1:  Cost: 1.01     Valid Accuracy: 0.541
# Epoch  6, CIFAR-10 Batch 2:  Cost: 0.964    Valid Accuracy: 0.539
# Epoch  6, CIFAR-10 Batch 3:  Cost: 0.865    Valid Accuracy: 0.527
# Epoch  6, CIFAR-10 Batch 4:  Cost: 0.88     Valid Accuracy: 0.533
# Epoch  6, CIFAR-10 Batch 5:  Cost: 0.924    Valid Accuracy: 0.538
# Epoch  7, CIFAR-10 Batch 1:  Cost: 0.966    Valid Accuracy: 0.551
# Epoch  7, CIFAR-10 Batch 2:  Cost: 0.918    Valid Accuracy: 0.543
# Epoch  7, CIFAR-10 Batch 3:  Cost: 0.817    Valid Accuracy: 0.54
# Epoch  7, CIFAR-10 Batch 4:  Cost: 0.788    Valid Accuracy: 0.542
# Epoch  7, CIFAR-10 Batch 5:  Cost: 0.795    Valid Accuracy: 0.552
# Epoch  8, CIFAR-10 Batch 1:  Cost: 0.879    Valid Accuracy: 0.545
# Epoch  8, CIFAR-10 Batch 2:  Cost: 0.841    Valid Accuracy: 0.551
# Epoch  8, CIFAR-10 Batch 3:  Cost: 0.757    Valid Accuracy: 0.545
# Epoch  8, CIFAR-10 Batch 4:  Cost: 0.728    Valid Accuracy: 0.539
# Epoch  8, CIFAR-10 Batch 5:  Cost: 0.786    Valid Accuracy: 0.551
# Epoch  9, CIFAR-10 Batch 1:  Cost: 0.819    Valid Accuracy: 0.551
# Epoch  9, CIFAR-10 Batch 2:  Cost: 0.789    Valid Accuracy: 0.554
# Epoch  9, CIFAR-10 Batch 3:  Cost: 0.725    Valid Accuracy: 0.538
# Epoch  9, CIFAR-10 Batch 4:  Cost: 0.703    Valid Accuracy: 0.551
# Epoch  9, CIFAR-10 Batch 5:  Cost: 0.733    Valid Accuracy: 0.545
# Epoch 10, CIFAR-10 Batch 1:  Cost: 0.783    Valid Accuracy: 0.551
# Epoch 10, CIFAR-10 Batch 2:  Cost: 0.74     Valid Accuracy: 0.556
# Epoch 10, CIFAR-10 Batch 3:  Cost: 0.68     Valid Accuracy: 0.552
# Epoch 10, CIFAR-10 Batch 4:  Cost: 0.625    Valid Accuracy: 0.563
# Epoch 10, CIFAR-10 Batch 5:  Cost: 0.667    Valid Accuracy: 0.557
# Epoch 11, CIFAR-10 Batch 1:  Cost: 0.741    Valid Accuracy: 0.56
# Epoch 11, CIFAR-10 Batch 2:  Cost: 0.799    Valid Accuracy: 0.541
# Epoch 11, CIFAR-10 Batch 3:  Cost: 0.667    Valid Accuracy: 0.543
# Epoch 11, CIFAR-10 Batch 4:  Cost: 0.611    Valid Accuracy: 0.573
# Epoch 11, CIFAR-10 Batch 5:  Cost: 0.643    Valid Accuracy: 0.565
# Epoch 12, CIFAR-10 Batch 1:  Cost: 0.697    Valid Accuracy: 0.561
# Epoch 12, CIFAR-10 Batch 2:  Cost: 0.702    Valid Accuracy: 0.537
# Epoch 12, CIFAR-10 Batch 3:  Cost: 0.617    Valid Accuracy: 0.568
# Epoch 12, CIFAR-10 Batch 4:  Cost: 0.586    Valid Accuracy: 0.572
# Epoch 12, CIFAR-10 Batch 5:  Cost: 0.607    Valid Accuracy: 0.569
# Epoch 13, CIFAR-10 Batch 1:  Cost: 0.668    Valid Accuracy: 0.55
# Epoch 13, CIFAR-10 Batch 2:  Cost: 0.691    Valid Accuracy: 0.524
# Epoch 13, CIFAR-10 Batch 3:  Cost: 0.622    Valid Accuracy: 0.557
# Epoch 13, CIFAR-10 Batch 4:  Cost: 0.547    Valid Accuracy: 0.579
# Epoch 13, CIFAR-10 Batch 5:  Cost: 0.627    Valid Accuracy: 0.57
# Epoch 14, CIFAR-10 Batch 1:  Cost: 0.644    Valid Accuracy: 0.548
# Epoch 14, CIFAR-10 Batch 2:  Cost: 0.7      Valid Accuracy: 0.52
# Epoch 14, CIFAR-10 Batch 3:  Cost: 0.518    Valid Accuracy: 0.581
# Epoch 14, CIFAR-10 Batch 4:  Cost: 0.542    Valid Accuracy: 0.575
# Epoch 14, CIFAR-10 Batch 5:  Cost: 0.604    Valid Accuracy: 0.575
# Epoch 15, CIFAR-10 Batch 1:  Cost: 0.571    Valid Accuracy: 0.563
# Epoch 15, CIFAR-10 Batch 2:  Cost: 0.595    Valid Accuracy: 0.554
# Epoch 15, CIFAR-10 Batch 3:  Cost: 0.5      Valid Accuracy: 0.568
# Epoch 15, CIFAR-10 Batch 4:  Cost: 0.467    Valid Accuracy: 0.574
# Epoch 15, CIFAR-10 Batch 5:  Cost: 0.53     Valid Accuracy: 0.575
# Epoch 16, CIFAR-10 Batch 1:  Cost: 0.511    Valid Accuracy: 0.567
# Epoch 16, CIFAR-10 Batch 2:  Cost: 0.58     Valid Accuracy: 0.553
# Epoch 16, CIFAR-10 Batch 3:  Cost: 0.475    Valid Accuracy: 0.566
# Epoch 16, CIFAR-10 Batch 4:  Cost: 0.442    Valid Accuracy: 0.564
# Epoch 16, CIFAR-10 Batch 5:  Cost: 0.492    Valid Accuracy: 0.57
# Epoch 17, CIFAR-10 Batch 1:  Cost: 0.576    Valid Accuracy: 0.557
# Epoch 17, CIFAR-10 Batch 2:  Cost: 0.554    Valid Accuracy: 0.55
# Epoch 17, CIFAR-10 Batch 3:  Cost: 0.481    Valid Accuracy: 0.558
# Epoch 17, CIFAR-10 Batch 4:  Cost: 0.446    Valid Accuracy: 0.568
# Epoch 17, CIFAR-10 Batch 5:  Cost: 0.464    Valid Accuracy: 0.564
# Epoch 18, CIFAR-10 Batch 1:  Cost: 0.539    Valid Accuracy: 0.555
# Epoch 18, CIFAR-10 Batch 2:  Cost: 0.556    Valid Accuracy: 0.553
# Epoch 18, CIFAR-10 Batch 3:  Cost: 0.512    Valid Accuracy: 0.561
# Epoch 18, CIFAR-10 Batch 4:  Cost: 0.428    Valid Accuracy: 0.57
# Epoch 18, CIFAR-10 Batch 5:  Cost: 0.42     Valid Accuracy: 0.57
# Epoch 19, CIFAR-10 Batch 1:  Cost: 0.473    Valid Accuracy: 0.568
# Epoch 19, CIFAR-10 Batch 2:  Cost: 0.524    Valid Accuracy: 0.557
# Epoch 19, CIFAR-10 Batch 3:  Cost: 0.45     Valid Accuracy: 0.568
# Epoch 19, CIFAR-10 Batch 4:  Cost: 0.4      Valid Accuracy: 0.566
# Epoch 19, CIFAR-10 Batch 5:  Cost: 0.401    Valid Accuracy: 0.573
# Epoch 20, CIFAR-10 Batch 1:  Cost: 0.452    Valid Accuracy: 0.571
# Epoch 20, CIFAR-10 Batch 2:  Cost: 0.476    Valid Accuracy: 0.557
# Epoch 20, CIFAR-10 Batch 3:  Cost: 0.382    Valid Accuracy: 0.569
# Epoch 20, CIFAR-10 Batch 4:  Cost: 0.449    Valid Accuracy: 0.55
# Epoch 20, CIFAR-10 Batch 5:  Cost: 0.403    Valid Accuracy: 0.577
# Epoch 21, CIFAR-10 Batch 1:  Cost: 0.429    Valid Accuracy: 0.566
# Epoch 21, CIFAR-10 Batch 2:  Cost: 0.41     Valid Accuracy: 0.576
# Epoch 21, CIFAR-10 Batch 3:  Cost: 0.346    Valid Accuracy: 0.573
# Epoch 21, CIFAR-10 Batch 4:  Cost: 0.368    Valid Accuracy: 0.561
# Epoch 21, CIFAR-10 Batch 5:  Cost: 0.353    Valid Accuracy: 0.565
# Epoch 22, CIFAR-10 Batch 1:  Cost: 0.433    Valid Accuracy: 0.566
# Epoch 22, CIFAR-10 Batch 2:  Cost: 0.383    Valid Accuracy: 0.577
# Epoch 22, CIFAR-10 Batch 3:  Cost: 0.318    Valid Accuracy: 0.578
# Epoch 22, CIFAR-10 Batch 4:  Cost: 0.343    Valid Accuracy: 0.577
# Epoch 22, CIFAR-10 Batch 5:  Cost: 0.342    Valid Accuracy: 0.577
# Epoch 23, CIFAR-10 Batch 1:  Cost: 0.342    Valid Accuracy: 0.572
# Epoch 23, CIFAR-10 Batch 2:  Cost: 0.408    Valid Accuracy: 0.565
# Epoch 23, CIFAR-10 Batch 3:  Cost: 0.274    Valid Accuracy: 0.579
# Epoch 23, CIFAR-10 Batch 4:  Cost: 0.345    Valid Accuracy: 0.57
# Epoch 23, CIFAR-10 Batch 5:  Cost: 0.337    Valid Accuracy: 0.575
# Epoch 24, CIFAR-10 Batch 1:  Cost: 0.357    Valid Accuracy: 0.578
# Epoch 24, CIFAR-10 Batch 2:  Cost: 0.356    Valid Accuracy: 0.581
# Epoch 24, CIFAR-10 Batch 3:  Cost: 0.301    Valid Accuracy: 0.562
# Epoch 24, CIFAR-10 Batch 4:  Cost: 0.306    Valid Accuracy: 0.572
# Epoch 24, CIFAR-10 Batch 5:  Cost: 0.376    Valid Accuracy: 0.574
# Epoch 25, CIFAR-10 Batch 1:  Cost: 0.382    Valid Accuracy: 0.572
# Epoch 25, CIFAR-10 Batch 2:  Cost: 0.342    Valid Accuracy: 0.579
# Epoch 25, CIFAR-10 Batch 3:  Cost: 0.3      Valid Accuracy: 0.58
# Epoch 25, CIFAR-10 Batch 4:  Cost: 0.322    Valid Accuracy: 0.574
# Epoch 25, CIFAR-10 Batch 5:  Cost: 0.32     Valid Accuracy: 0.581
# Epoch 26, CIFAR-10 Batch 1:  Cost: 0.353    Valid Accuracy: 0.578
# Epoch 26, CIFAR-10 Batch 2:  Cost: 0.303    Valid Accuracy: 0.584
# Epoch 26, CIFAR-10 Batch 3:  Cost: 0.277    Valid Accuracy: 0.58
# Epoch 26, CIFAR-10 Batch 4:  Cost: 0.287    Valid Accuracy: 0.561
# Epoch 26, CIFAR-10 Batch 5:  Cost: 0.323    Valid Accuracy: 0.569
# Epoch 27, CIFAR-10 Batch 1:  Cost: 0.251    Valid Accuracy: 0.581
# Epoch 27, CIFAR-10 Batch 2:  Cost: 0.283    Valid Accuracy: 0.582
# Epoch 27, CIFAR-10 Batch 3:  Cost: 0.265    Valid Accuracy: 0.584
# Epoch 27, CIFAR-10 Batch 4:  Cost: 0.274    Valid Accuracy: 0.554
# Epoch 27, CIFAR-10 Batch 5:  Cost: 0.266    Valid Accuracy: 0.586
# Epoch 28, CIFAR-10 Batch 1:  Cost: 0.256    Valid Accuracy: 0.575
# Epoch 28, CIFAR-10 Batch 2:  Cost: 0.259    Valid Accuracy: 0.58
# Epoch 28, CIFAR-10 Batch 3:  Cost: 0.253    Valid Accuracy: 0.587
# Epoch 28, CIFAR-10 Batch 4:  Cost: 0.21     Valid Accuracy: 0.569
# Epoch 28, CIFAR-10 Batch 5:  Cost: 0.263    Valid Accuracy: 0.575
# Epoch 29, CIFAR-10 Batch 1:  Cost: 0.257    Valid Accuracy: 0.579
# Epoch 29, CIFAR-10 Batch 2:  Cost: 0.25     Valid Accuracy: 0.573
# Epoch 29, CIFAR-10 Batch 3:  Cost: 0.228    Valid Accuracy: 0.583
# Epoch 29, CIFAR-10 Batch 4:  Cost: 0.212    Valid Accuracy: 0.562
# Epoch 29, CIFAR-10 Batch 5:  Cost: 0.227    Valid Accuracy: 0.579
# Epoch 30, CIFAR-10 Batch 1:  Cost: 0.201    Valid Accuracy: 0.591
# Epoch 30, CIFAR-10 Batch 2:  Cost: 0.239    Valid Accuracy: 0.588
# Epoch 30, CIFAR-10 Batch 3:  Cost: 0.214    Valid Accuracy: 0.587
# Epoch 30, CIFAR-10 Batch 4:  Cost: 0.194    Valid Accuracy: 0.583
# Epoch 30, CIFAR-10 Batch 5:  Cost: 0.21     Valid Accuracy: 0.581
# Epoch 31, CIFAR-10 Batch 1:  Cost: 0.198    Valid Accuracy: 0.584
# Epoch 31, CIFAR-10 Batch 2:  Cost: 0.227    Valid Accuracy: 0.58
# Epoch 31, CIFAR-10 Batch 3:  Cost: 0.171    Valid Accuracy: 0.59
# Epoch 31, CIFAR-10 Batch 4:  Cost: 0.191    Valid Accuracy: 0.581
# Epoch 31, CIFAR-10 Batch 5:  Cost: 0.199    Valid Accuracy: 0.574
# Epoch 32, CIFAR-10 Batch 1:  Cost: 0.198    Valid Accuracy: 0.581
# Epoch 32, CIFAR-10 Batch 2:  Cost: 0.201    Valid Accuracy: 0.578
# Epoch 32, CIFAR-10 Batch 3:  Cost: 0.163    Valid Accuracy: 0.59
# Epoch 32, CIFAR-10 Batch 4:  Cost: 0.159    Valid Accuracy: 0.591
# Epoch 32, CIFAR-10 Batch 5:  Cost: 0.178    Valid Accuracy: 0.578
# Epoch 33, CIFAR-10 Batch 1:  Cost: 0.176    Valid Accuracy: 0.574
# Epoch 33, CIFAR-10 Batch 2:  Cost: 0.176    Valid Accuracy: 0.586
# Epoch 33, CIFAR-10 Batch 3:  Cost: 0.16     Valid Accuracy: 0.593
# Epoch 33, CIFAR-10 Batch 4:  Cost: 0.129    Valid Accuracy: 0.585
# Epoch 33, CIFAR-10 Batch 5:  Cost: 0.137    Valid Accuracy: 0.576
# Epoch 34, CIFAR-10 Batch 1:  Cost: 0.164    Valid Accuracy: 0.566
# Epoch 34, CIFAR-10 Batch 2:  Cost: 0.164    Valid Accuracy: 0.582
# Epoch 34, CIFAR-10 Batch 3:  Cost: 0.138    Valid Accuracy: 0.59
# Epoch 34, CIFAR-10 Batch 4:  Cost: 0.112    Valid Accuracy: 0.59
# Epoch 34, CIFAR-10 Batch 5:  Cost: 0.115    Valid Accuracy: 0.588
# Epoch 35, CIFAR-10 Batch 1:  Cost: 0.157    Valid Accuracy: 0.579
# Epoch 35, CIFAR-10 Batch 2:  Cost: 0.136    Valid Accuracy: 0.579
# Epoch 35, CIFAR-10 Batch 3:  Cost: 0.127    Valid Accuracy: 0.587
# Epoch 35, CIFAR-10 Batch 4:  Cost: 0.105    Valid Accuracy: 0.59
# Epoch 35, CIFAR-10 Batch 5:  Cost: 0.0934   Valid Accuracy: 0.587
# Epoch 36, CIFAR-10 Batch 1:  Cost: 0.117    Valid Accuracy: 0.578
# Epoch 36, CIFAR-10 Batch 2:  Cost: 0.136    Valid Accuracy: 0.592
# Epoch 36, CIFAR-10 Batch 3:  Cost: 0.131    Valid Accuracy: 0.576
# Epoch 36, CIFAR-10 Batch 4:  Cost: 0.0886   Valid Accuracy: 0.589
# Epoch 36, CIFAR-10 Batch 5:  Cost: 0.0915   Valid Accuracy: 0.58
# Epoch 37, CIFAR-10 Batch 1:  Cost: 0.112    Valid Accuracy: 0.59
# Epoch 37, CIFAR-10 Batch 2:  Cost: 0.105    Valid Accuracy: 0.576
# Epoch 37, CIFAR-10 Batch 3:  Cost: 0.0931   Valid Accuracy: 0.58
# Epoch 37, CIFAR-10 Batch 4:  Cost: 0.108    Valid Accuracy: 0.576
# Epoch 37, CIFAR-10 Batch 5:  Cost: 0.0757   Valid Accuracy: 0.587
# Epoch 38, CIFAR-10 Batch 1:  Cost: 0.111    Valid Accuracy: 0.596
# Epoch 38, CIFAR-10 Batch 2:  Cost: 0.0778   Valid Accuracy: 0.583
# Epoch 38, CIFAR-10 Batch 3:  Cost: 0.0659   Valid Accuracy: 0.6
# Epoch 38, CIFAR-10 Batch 4:  Cost: 0.1      Valid Accuracy: 0.581
# Epoch 38, CIFAR-10 Batch 5:  Cost: 0.0858   Valid Accuracy: 0.579
# Epoch 39, CIFAR-10 Batch 1:  Cost: 0.11     Valid Accuracy: 0.582
# Epoch 39, CIFAR-10 Batch 2:  Cost: 0.0824   Valid Accuracy: 0.577
# Epoch 39, CIFAR-10 Batch 3:  Cost: 0.0764   Valid Accuracy: 0.589
# Epoch 39, CIFAR-10 Batch 4:  Cost: 0.079    Valid Accuracy: 0.579
# Epoch 39, CIFAR-10 Batch 5:  Cost: 0.0823   Valid Accuracy: 0.578
# Epoch 40, CIFAR-10 Batch 1:  Cost: 0.0804   Valid Accuracy: 0.584
# Epoch 40, CIFAR-10 Batch 2:  Cost: 0.0775   Valid Accuracy: 0.586
# Epoch 40, CIFAR-10 Batch 3:  Cost: 0.0626   Valid Accuracy: 0.599
# Epoch 40, CIFAR-10 Batch 4:  Cost: 0.0742   Valid Accuracy: 0.573
# Epoch 40, CIFAR-10 Batch 5:  Cost: 0.0704   Valid Accuracy: 0.58
# Epoch 41, CIFAR-10 Batch 1:  Cost: 0.0714   Valid Accuracy: 0.587
# Epoch 41, CIFAR-10 Batch 2:  Cost: 0.0483   Valid Accuracy: 0.586
# Epoch 41, CIFAR-10 Batch 3:  Cost: 0.0669   Valid Accuracy: 0.601
# Epoch 41, CIFAR-10 Batch 4:  Cost: 0.071    Valid Accuracy: 0.572
# Epoch 41, CIFAR-10 Batch 5:  Cost: 0.07     Valid Accuracy: 0.572
# Epoch 42, CIFAR-10 Batch 1:  Cost: 0.0781   Valid Accuracy: 0.587
# Epoch 42, CIFAR-10 Batch 2:  Cost: 0.0522   Valid Accuracy: 0.59
# Epoch 42, CIFAR-10 Batch 3:  Cost: 0.0678   Valid Accuracy: 0.597
# Epoch 42, CIFAR-10 Batch 4:  Cost: 0.055    Valid Accuracy: 0.569
# Epoch 42, CIFAR-10 Batch 5:  Cost: 0.0639   Valid Accuracy: 0.585
# Epoch 43, CIFAR-10 Batch 1:  Cost: 0.0567   Valid Accuracy: 0.59
# Epoch 43, CIFAR-10 Batch 2:  Cost: 0.0517   Valid Accuracy: 0.581
# Epoch 43, CIFAR-10 Batch 3:  Cost: 0.0551   Valid Accuracy: 0.601
# Epoch 43, CIFAR-10 Batch 4:  Cost: 0.0571   Valid Accuracy: 0.563
# Epoch 43, CIFAR-10 Batch 5:  Cost: 0.0659   Valid Accuracy: 0.582
# Epoch 44, CIFAR-10 Batch 1:  Cost: 0.0729   Valid Accuracy: 0.588
# Epoch 44, CIFAR-10 Batch 2:  Cost: 0.0669   Valid Accuracy: 0.574
# Epoch 44, CIFAR-10 Batch 3:  Cost: 0.0613   Valid Accuracy: 0.595
# Epoch 44, CIFAR-10 Batch 4:  Cost: 0.0473   Valid Accuracy: 0.569
# Epoch 44, CIFAR-10 Batch 5:  Cost: 0.0551   Valid Accuracy: 0.575
# Epoch 45, CIFAR-10 Batch 1:  Cost: 0.073    Valid Accuracy: 0.576
# Epoch 45, CIFAR-10 Batch 2:  Cost: 0.0532   Valid Accuracy: 0.582
# Epoch 45, CIFAR-10 Batch 3:  Cost: 0.062    Valid Accuracy: 0.584
# Epoch 45, CIFAR-10 Batch 4:  Cost: 0.0513   Valid Accuracy: 0.593
# Epoch 45, CIFAR-10 Batch 5:  Cost: 0.0477   Valid Accuracy: 0.574
# Epoch 46, CIFAR-10 Batch 1:  Cost: 0.0616   Valid Accuracy: 0.574
# Epoch 46, CIFAR-10 Batch 2:  Cost: 0.0482   Valid Accuracy: 0.584
# Epoch 46, CIFAR-10 Batch 3:  Cost: 0.0531   Valid Accuracy: 0.587
# Epoch 46, CIFAR-10 Batch 4:  Cost: 0.0376   Valid Accuracy: 0.592
# Epoch 46, CIFAR-10 Batch 5:  Cost: 0.0405   Valid Accuracy: 0.583
# Epoch 47, CIFAR-10 Batch 1:  Cost: 0.0502   Valid Accuracy: 0.592
# Epoch 47, CIFAR-10 Batch 2:  Cost: 0.0629   Valid Accuracy: 0.595
# Epoch 47, CIFAR-10 Batch 3:  Cost: 0.0401   Valid Accuracy: 0.595
# Epoch 47, CIFAR-10 Batch 4:  Cost: 0.0493   Valid Accuracy: 0.591
# Epoch 47, CIFAR-10 Batch 5:  Cost: 0.0495   Valid Accuracy: 0.595
# Epoch 48, CIFAR-10 Batch 1:  Cost: 0.0499   Valid Accuracy: 0.586
# Epoch 48, CIFAR-10 Batch 2:  Cost: 0.0591   Valid Accuracy: 0.598
# Epoch 48, CIFAR-10 Batch 3:  Cost: 0.0399   Valid Accuracy: 0.595
# Epoch 48, CIFAR-10 Batch 4:  Cost: 0.0484   Valid Accuracy: 0.588
# Epoch 48, CIFAR-10 Batch 5:  Cost: 0.048    Valid Accuracy: 0.588
# Epoch 49, CIFAR-10 Batch 1:  Cost: 0.0569   Valid Accuracy: 0.594
# Epoch 49, CIFAR-10 Batch 2:  Cost: 0.0329   Valid Accuracy: 0.595
# Epoch 49, CIFAR-10 Batch 3:  Cost: 0.0274   Valid Accuracy: 0.596
# Epoch 49, CIFAR-10 Batch 4:  Cost: 0.0256   Valid Accuracy: 0.577
# Epoch 49, CIFAR-10 Batch 5:  Cost: 0.0517   Valid Accuracy: 0.588
# Epoch 50, CIFAR-10 Batch 1:  Cost: 0.0316   Valid Accuracy: 0.594
# Epoch 50, CIFAR-10 Batch 2:  Cost: 0.0321   Valid Accuracy: 0.592
# Epoch 50, CIFAR-10 Batch 3:  Cost: 0.0238   Valid Accuracy: 0.597
# Epoch 50, CIFAR-10 Batch 4:  Cost: 0.0306   Valid Accuracy: 0.59
# Epoch 50, CIFAR-10 Batch 5:  Cost: 0.0494   Valid Accuracy: 0.594
# Epoch 51, CIFAR-10 Batch 1:  Cost: 0.0407   Valid Accuracy: 0.592
# Epoch 51, CIFAR-10 Batch 2:  Cost: 0.0284   Valid Accuracy: 0.598
# Epoch 51, CIFAR-10 Batch 3:  Cost: 0.0262   Valid Accuracy: 0.597
# Epoch 51, CIFAR-10 Batch 4:  Cost: 0.0377   Valid Accuracy: 0.595
# Epoch 51, CIFAR-10 Batch 5:  Cost: 0.0397   Valid Accuracy: 0.582
# Epoch 52, CIFAR-10 Batch 1:  Cost: 0.0336   Valid Accuracy: 0.593
# Epoch 52, CIFAR-10 Batch 2:  Cost: 0.0294   Valid Accuracy: 0.591
# Epoch 52, CIFAR-10 Batch 3:  Cost: 0.0221   Valid Accuracy: 0.595
# Epoch 52, CIFAR-10 Batch 4:  Cost: 0.0145   Valid Accuracy: 0.594
# Epoch 52, CIFAR-10 Batch 5:  Cost: 0.0235   Valid Accuracy: 0.595
# Epoch 53, CIFAR-10 Batch 1:  Cost: 0.0329   Valid Accuracy: 0.589
# Epoch 53, CIFAR-10 Batch 2:  Cost: 0.0235   Valid Accuracy: 0.596
# Epoch 53, CIFAR-10 Batch 3:  Cost: 0.0212   Valid Accuracy: 0.595
# Epoch 53, CIFAR-10 Batch 4:  Cost: 0.0288   Valid Accuracy: 0.589
# Epoch 53, CIFAR-10 Batch 5:  Cost: 0.0242   Valid Accuracy: 0.59
# Epoch 54, CIFAR-10 Batch 1:  Cost: 0.0251   Valid Accuracy: 0.593
# Epoch 54, CIFAR-10 Batch 2:  Cost: 0.0266   Valid Accuracy: 0.588
# Epoch 54, CIFAR-10 Batch 3:  Cost: 0.0191   Valid Accuracy: 0.595
# Epoch 54, CIFAR-10 Batch 4:  Cost: 0.0226   Valid Accuracy: 0.598
# Epoch 54, CIFAR-10 Batch 5:  Cost: 0.0342   Valid Accuracy: 0.599
# Epoch 55, CIFAR-10 Batch 1:  Cost: 0.0195   Valid Accuracy: 0.596
# Epoch 55, CIFAR-10 Batch 2:  Cost: 0.0311   Valid Accuracy: 0.585
# Epoch 55, CIFAR-10 Batch 3:  Cost: 0.0245   Valid Accuracy: 0.598
# Epoch 55, CIFAR-10 Batch 4:  Cost: 0.0135   Valid Accuracy: 0.593
# Epoch 55, CIFAR-10 Batch 5:  Cost: 0.0202   Valid Accuracy: 0.592
# Epoch 56, CIFAR-10 Batch 1:  Cost: 0.0183   Valid Accuracy: 0.598
# Epoch 56, CIFAR-10 Batch 2:  Cost: 0.0236   Valid Accuracy: 0.602
# Epoch 56, CIFAR-10 Batch 3:  Cost: 0.0166   Valid Accuracy: 0.599
# Epoch 56, CIFAR-10 Batch 4:  Cost: 0.0242   Valid Accuracy: 0.6
# Epoch 56, CIFAR-10 Batch 5:  Cost: 0.021    Valid Accuracy: 0.595
# Epoch 57, CIFAR-10 Batch 1:  Cost: 0.0177   Valid Accuracy: 0.599
# Epoch 57, CIFAR-10 Batch 2:  Cost: 0.0238   Valid Accuracy: 0.599
# Epoch 57, CIFAR-10 Batch 3:  Cost: 0.0227   Valid Accuracy: 0.593
# Epoch 57, CIFAR-10 Batch 4:  Cost: 0.0104   Valid Accuracy: 0.604
# Epoch 57, CIFAR-10 Batch 5:  Cost: 0.0168   Valid Accuracy: 0.606
# Epoch 58, CIFAR-10 Batch 1:  Cost: 0.0157   Valid Accuracy: 0.602
# Epoch 58, CIFAR-10 Batch 2:  Cost: 0.0203   Valid Accuracy: 0.593
# Epoch 58, CIFAR-10 Batch 3:  Cost: 0.0267   Valid Accuracy: 0.592
# Epoch 58, CIFAR-10 Batch 4:  Cost: 0.0119   Valid Accuracy: 0.595
# Epoch 58, CIFAR-10 Batch 5:  Cost: 0.0174   Valid Accuracy: 0.601
# Epoch 59, CIFAR-10 Batch 1:  Cost: 0.0207   Valid Accuracy: 0.598
# Epoch 59, CIFAR-10 Batch 2:  Cost: 0.0215   Valid Accuracy: 0.592
# Epoch 59, CIFAR-10 Batch 3:  Cost: 0.0309   Valid Accuracy: 0.588
# Epoch 59, CIFAR-10 Batch 4:  Cost: 0.0141   Valid Accuracy: 0.593
# Epoch 59, CIFAR-10 Batch 5:  Cost: 0.015    Valid Accuracy: 0.606
# Epoch 60, CIFAR-10 Batch 1:  Cost: 0.0151   Valid Accuracy: 0.594
# Epoch 60, CIFAR-10 Batch 2:  Cost: 0.0173   Valid Accuracy: 0.59
# Epoch 60, CIFAR-10 Batch 3:  Cost: 0.0143   Valid Accuracy: 0.597
# Epoch 60, CIFAR-10 Batch 4:  Cost: 0.0139   Valid Accuracy: 0.59
# Epoch 60, CIFAR-10 Batch 5:  Cost: 0.0154   Valid Accuracy: 0.601
# Epoch 61, CIFAR-10 Batch 1:  Cost: 0.0107   Valid Accuracy: 0.603
# Epoch 61, CIFAR-10 Batch 2:  Cost: 0.0155   Valid Accuracy: 0.593
# Epoch 61, CIFAR-10 Batch 3:  Cost: 0.0151   Valid Accuracy: 0.592
# Epoch 61, CIFAR-10 Batch 4:  Cost: 0.00881  Valid Accuracy: 0.594
# Epoch 61, CIFAR-10 Batch 5:  Cost: 0.0179   Valid Accuracy: 0.603
# Epoch 62, CIFAR-10 Batch 1:  Cost: 0.00919  Valid Accuracy: 0.607
# Epoch 62, CIFAR-10 Batch 2:  Cost: 0.0144   Valid Accuracy: 0.605
# Epoch 62, CIFAR-10 Batch 3:  Cost: 0.0194   Valid Accuracy: 0.598
# Epoch 62, CIFAR-10 Batch 4:  Cost: 0.0081   Valid Accuracy: 0.601
# Epoch 62, CIFAR-10 Batch 5:  Cost: 0.0197   Valid Accuracy: 0.6
# Epoch 63, CIFAR-10 Batch 1:  Cost: 0.0258   Valid Accuracy: 0.595
# Epoch 63, CIFAR-10 Batch 2:  Cost: 0.0122   Valid Accuracy: 0.593
# Epoch 63, CIFAR-10 Batch 3:  Cost: 0.013    Valid Accuracy: 0.599
# Epoch 63, CIFAR-10 Batch 4:  Cost: 0.0102   Valid Accuracy: 0.597
# Epoch 63, CIFAR-10 Batch 5:  Cost: 0.0186   Valid Accuracy: 0.596
# Epoch 64, CIFAR-10 Batch 1:  Cost: 0.0158   Valid Accuracy: 0.605
# Epoch 64, CIFAR-10 Batch 2:  Cost: 0.017    Valid Accuracy: 0.588
# Epoch 64, CIFAR-10 Batch 3:  Cost: 0.0292   Valid Accuracy: 0.586
# Epoch 64, CIFAR-10 Batch 4:  Cost: 0.0157   Valid Accuracy: 0.596
# Epoch 64, CIFAR-10 Batch 5:  Cost: 0.0178   Valid Accuracy: 0.591
# Epoch 65, CIFAR-10 Batch 1:  Cost: 0.00997  Valid Accuracy: 0.598
# Epoch 65, CIFAR-10 Batch 2:  Cost: 0.0103   Valid Accuracy: 0.589
# Epoch 65, CIFAR-10 Batch 3:  Cost: 0.014    Valid Accuracy: 0.596
# Epoch 65, CIFAR-10 Batch 4:  Cost: 0.0114   Valid Accuracy: 0.595
# Epoch 65, CIFAR-10 Batch 5:  Cost: 0.0139   Valid Accuracy: 0.604
# Epoch 66, CIFAR-10 Batch 1:  Cost: 0.0123   Valid Accuracy: 0.608
# Epoch 66, CIFAR-10 Batch 2:  Cost: 0.00776  Valid Accuracy: 0.598
# Epoch 66, CIFAR-10 Batch 3:  Cost: 0.0186   Valid Accuracy: 0.595
# Epoch 66, CIFAR-10 Batch 4:  Cost: 0.00634  Valid Accuracy: 0.602
# Epoch 66, CIFAR-10 Batch 5:  Cost: 0.00896  Valid Accuracy: 0.603
# Epoch 67, CIFAR-10 Batch 1:  Cost: 0.0102   Valid Accuracy: 0.599
# Epoch 67, CIFAR-10 Batch 2:  Cost: 0.00713  Valid Accuracy: 0.6
# Epoch 67, CIFAR-10 Batch 3:  Cost: 0.0104   Valid Accuracy: 0.599
# Epoch 67, CIFAR-10 Batch 4:  Cost: 0.0111   Valid Accuracy: 0.602
# Epoch 67, CIFAR-10 Batch 5:  Cost: 0.0205   Valid Accuracy: 0.597
# Epoch 68, CIFAR-10 Batch 1:  Cost: 0.00899  Valid Accuracy: 0.606
# Epoch 68, CIFAR-10 Batch 2:  Cost: 0.00833  Valid Accuracy: 0.603
# Epoch 68, CIFAR-10 Batch 3:  Cost: 0.00689  Valid Accuracy: 0.601
# Epoch 68, CIFAR-10 Batch 4:  Cost: 0.00923  Valid Accuracy: 0.604
# Epoch 68, CIFAR-10 Batch 5:  Cost: 0.00877  Valid Accuracy: 0.594
# Epoch 69, CIFAR-10 Batch 1:  Cost: 0.00609  Valid Accuracy: 0.605
# Epoch 69, CIFAR-10 Batch 2:  Cost: 0.0105   Valid Accuracy: 0.598
# Epoch 69, CIFAR-10 Batch 3:  Cost: 0.00576  Valid Accuracy: 0.598
# Epoch 69, CIFAR-10 Batch 4:  Cost: 0.00528  Valid Accuracy: 0.603
# Epoch 69, CIFAR-10 Batch 5:  Cost: 0.00596  Valid Accuracy: 0.606
# Epoch 70, CIFAR-10 Batch 1:  Cost: 0.00757  Valid Accuracy: 0.602
# Epoch 70, CIFAR-10 Batch 2:  Cost: 0.0099   Valid Accuracy: 0.59
# Epoch 70, CIFAR-10 Batch 3:  Cost: 0.006    Valid Accuracy: 0.598
# Epoch 70, CIFAR-10 Batch 4:  Cost: 0.0119   Valid Accuracy: 0.59
# Epoch 70, CIFAR-10 Batch 5:  Cost: 0.00601  Valid Accuracy: 0.596
# Epoch 71, CIFAR-10 Batch 1:  Cost: 0.00655  Valid Accuracy: 0.601
# Epoch 71, CIFAR-10 Batch 2:  Cost: 0.0119   Valid Accuracy: 0.599
# Epoch 71, CIFAR-10 Batch 3:  Cost: 0.00586  Valid Accuracy: 0.59
# Epoch 71, CIFAR-10 Batch 4:  Cost: 0.00566  Valid Accuracy: 0.589
# Epoch 71, CIFAR-10 Batch 5:  Cost: 0.00816  Valid Accuracy: 0.596
# Epoch 72, CIFAR-10 Batch 1:  Cost: 0.00878  Valid Accuracy: 0.598
# Epoch 72, CIFAR-10 Batch 2:  Cost: 0.00944  Valid Accuracy: 0.591
# Epoch 72, CIFAR-10 Batch 3:  Cost: 0.00566  Valid Accuracy: 0.594
# Epoch 72, CIFAR-10 Batch 4:  Cost: 0.0076   Valid Accuracy: 0.59
# Epoch 72, CIFAR-10 Batch 5:  Cost: 0.00349  Valid Accuracy: 0.604
# Epoch 73, CIFAR-10 Batch 1:  Cost: 0.006    Valid Accuracy: 0.602
# Epoch 73, CIFAR-10 Batch 2:  Cost: 0.00606  Valid Accuracy: 0.596
# Epoch 73, CIFAR-10 Batch 3:  Cost: 0.00748  Valid Accuracy: 0.592
# Epoch 73, CIFAR-10 Batch 4:  Cost: 0.0056   Valid Accuracy: 0.589
# Epoch 73, CIFAR-10 Batch 5:  Cost: 0.00496  Valid Accuracy: 0.597
# Epoch 74, CIFAR-10 Batch 1:  Cost: 0.00778  Valid Accuracy: 0.606
# Epoch 74, CIFAR-10 Batch 2:  Cost: 0.00617  Valid Accuracy: 0.605
# Epoch 74, CIFAR-10 Batch 3:  Cost: 0.0117   Valid Accuracy: 0.593
# Epoch 74, CIFAR-10 Batch 4:  Cost: 0.00995  Valid Accuracy: 0.586
# Epoch 74, CIFAR-10 Batch 5:  Cost: 0.00741  Valid Accuracy: 0.595
# Epoch 75, CIFAR-10 Batch 1:  Cost: 0.00713  Valid Accuracy: 0.6
# Epoch 75, CIFAR-10 Batch 2:  Cost: 0.00338  Valid Accuracy: 0.603
# Epoch 75, CIFAR-10 Batch 3:  Cost: 0.00686  Valid Accuracy: 0.596
# Epoch 75, CIFAR-10 Batch 4:  Cost: 0.0105   Valid Accuracy: 0.587
# Epoch 75, CIFAR-10 Batch 5:  Cost: 0.00925  Valid Accuracy: 0.591
# Epoch 76, CIFAR-10 Batch 1:  Cost: 0.00703  Valid Accuracy: 0.596
# Epoch 76, CIFAR-10 Batch 2:  Cost: 0.00454  Valid Accuracy: 0.604
# Epoch 76, CIFAR-10 Batch 3:  Cost: 0.00476  Valid Accuracy: 0.606
# Epoch 76, CIFAR-10 Batch 4:  Cost: 0.00663  Valid Accuracy: 0.581
# Epoch 76, CIFAR-10 Batch 5:  Cost: 0.00924  Valid Accuracy: 0.59
# Epoch 77, CIFAR-10 Batch 1:  Cost: 0.00602  Valid Accuracy: 0.588
# Epoch 77, CIFAR-10 Batch 2:  Cost: 0.00431  Valid Accuracy: 0.604
# Epoch 77, CIFAR-10 Batch 3:  Cost: 0.0136   Valid Accuracy: 0.603
# Epoch 77, CIFAR-10 Batch 4:  Cost: 0.00811  Valid Accuracy: 0.583
# Epoch 77, CIFAR-10 Batch 5:  Cost: 0.00913  Valid Accuracy: 0.582
# Epoch 78, CIFAR-10 Batch 1:  Cost: 0.00591  Valid Accuracy: 0.589
# Epoch 78, CIFAR-10 Batch 2:  Cost: 0.00563  Valid Accuracy: 0.595
# Epoch 78, CIFAR-10 Batch 3:  Cost: 0.00927  Valid Accuracy: 0.602
# Epoch 78, CIFAR-10 Batch 4:  Cost: 0.00526  Valid Accuracy: 0.597
# Epoch 78, CIFAR-10 Batch 5:  Cost: 0.0107   Valid Accuracy: 0.581
# Epoch 79, CIFAR-10 Batch 1:  Cost: 0.00782  Valid Accuracy: 0.594
# Epoch 79, CIFAR-10 Batch 2:  Cost: 0.00595  Valid Accuracy: 0.595
# Epoch 79, CIFAR-10 Batch 3:  Cost: 0.00669  Valid Accuracy: 0.595
# Epoch 79, CIFAR-10 Batch 4:  Cost: 0.00592  Valid Accuracy: 0.593
# Epoch 79, CIFAR-10 Batch 5:  Cost: 0.00822  Valid Accuracy: 0.594
# Epoch 80, CIFAR-10 Batch 1:  Cost: 0.00652  Valid Accuracy: 0.589
# Epoch 80, CIFAR-10 Batch 2:  Cost: 0.00843  Valid Accuracy: 0.591
# Epoch 80, CIFAR-10 Batch 3:  Cost: 0.00701  Valid Accuracy: 0.597
# Epoch 80, CIFAR-10 Batch 4:  Cost: 0.00784  Valid Accuracy: 0.592
# Epoch 80, CIFAR-10 Batch 5:  Cost: 0.0115   Valid Accuracy: 0.594
# Epoch 81, CIFAR-10 Batch 1:  Cost: 0.00809  Valid Accuracy: 0.596
# Epoch 81, CIFAR-10 Batch 2:  Cost: 0.00459  Valid Accuracy: 0.594
# Epoch 81, CIFAR-10 Batch 3:  Cost: 0.00624  Valid Accuracy: 0.596
# Epoch 81, CIFAR-10 Batch 4:  Cost: 0.0039   Valid Accuracy: 0.593
# Epoch 81, CIFAR-10 Batch 5:  Cost: 0.00717  Valid Accuracy: 0.593
# Epoch 82, CIFAR-10 Batch 1:  Cost: 0.00505  Valid Accuracy: 0.588
# Epoch 82, CIFAR-10 Batch 2:  Cost: 0.00401  Valid Accuracy: 0.595
# Epoch 82, CIFAR-10 Batch 3:  Cost: 0.00693  Valid Accuracy: 0.596
# Epoch 82, CIFAR-10 Batch 4:  Cost: 0.00607  Valid Accuracy: 0.591
# Epoch 82, CIFAR-10 Batch 5:  Cost: 0.00508  Valid Accuracy: 0.599
# Epoch 83, CIFAR-10 Batch 1:  Cost: 0.00548  Valid Accuracy: 0.591
# Epoch 83, CIFAR-10 Batch 2:  Cost: 0.00737  Valid Accuracy: 0.594
# Epoch 83, CIFAR-10 Batch 3:  Cost: 0.00533  Valid Accuracy: 0.592
# Epoch 83, CIFAR-10 Batch 4:  Cost: 0.0057   Valid Accuracy: 0.598
# Epoch 83, CIFAR-10 Batch 5:  Cost: 0.0036   Valid Accuracy: 0.598
# Epoch 84, CIFAR-10 Batch 1:  Cost: 0.0111   Valid Accuracy: 0.588
# Epoch 84, CIFAR-10 Batch 2:  Cost: 0.00421  Valid Accuracy: 0.601
# Epoch 84, CIFAR-10 Batch 3:  Cost: 0.00474  Valid Accuracy: 0.606
# Epoch 84, CIFAR-10 Batch 4:  Cost: 0.00464  Valid Accuracy: 0.589
# Epoch 84, CIFAR-10 Batch 5:  Cost: 0.00597  Valid Accuracy: 0.596
# Epoch 85, CIFAR-10 Batch 1:  Cost: 0.00637  Valid Accuracy: 0.581
# Epoch 85, CIFAR-10 Batch 2:  Cost: 0.00287  Valid Accuracy: 0.599
# Epoch 85, CIFAR-10 Batch 3:  Cost: 0.00714  Valid Accuracy: 0.595
# Epoch 85, CIFAR-10 Batch 4:  Cost: 0.00339  Valid Accuracy: 0.595
# Epoch 85, CIFAR-10 Batch 5:  Cost: 0.0131   Valid Accuracy: 0.592
# Epoch 86, CIFAR-10 Batch 1:  Cost: 0.00674  Valid Accuracy: 0.59
# Epoch 86, CIFAR-10 Batch 2:  Cost: 0.00749  Valid Accuracy: 0.594
# Epoch 86, CIFAR-10 Batch 3:  Cost: 0.00596  Valid Accuracy: 0.59
# Epoch 86, CIFAR-10 Batch 4:  Cost: 0.00323  Valid Accuracy: 0.593
# Epoch 86, CIFAR-10 Batch 5:  Cost: 0.00594  Valid Accuracy: 0.6
# Epoch 87, CIFAR-10 Batch 1:  Cost: 0.00778  Valid Accuracy: 0.593
# Epoch 87, CIFAR-10 Batch 2:  Cost: 0.00919  Valid Accuracy: 0.594
# Epoch 87, CIFAR-10 Batch 3:  Cost: 0.01     Valid Accuracy: 0.591
# Epoch 87, CIFAR-10 Batch 4:  Cost: 0.00809  Valid Accuracy: 0.59
# Epoch 87, CIFAR-10 Batch 5:  Cost: 0.0045   Valid Accuracy: 0.598
# Epoch 88, CIFAR-10 Batch 1:  Cost: 0.0144   Valid Accuracy: 0.6
# Epoch 88, CIFAR-10 Batch 2:  Cost: 0.00378  Valid Accuracy: 0.605
# Epoch 88, CIFAR-10 Batch 3:  Cost: 0.00508  Valid Accuracy: 0.593
# Epoch 88, CIFAR-10 Batch 4:  Cost: 0.00549  Valid Accuracy: 0.602
# Epoch 88, CIFAR-10 Batch 5:  Cost: 0.00648  Valid Accuracy: 0.589
# Epoch 89, CIFAR-10 Batch 1:  Cost: 0.0112   Valid Accuracy: 0.591
# Epoch 89, CIFAR-10 Batch 2:  Cost: 0.00647  Valid Accuracy: 0.599
# Epoch 89, CIFAR-10 Batch 3:  Cost: 0.00834  Valid Accuracy: 0.597
# Epoch 89, CIFAR-10 Batch 4:  Cost: 0.0041   Valid Accuracy: 0.599
# Epoch 89, CIFAR-10 Batch 5:  Cost: 0.00842  Valid Accuracy: 0.602
# Epoch 90, CIFAR-10 Batch 1:  Cost: 0.00384  Valid Accuracy: 0.593
# Epoch 90, CIFAR-10 Batch 2:  Cost: 0.00468  Valid Accuracy: 0.591
# Epoch 90, CIFAR-10 Batch 3:  Cost: 0.00878  Valid Accuracy: 0.589
# Epoch 90, CIFAR-10 Batch 4:  Cost: 0.00477  Valid Accuracy: 0.599
# Epoch 90, CIFAR-10 Batch 5:  Cost: 0.00422  Valid Accuracy: 0.597
# Epoch 91, CIFAR-10 Batch 1:  Cost: 0.00265  Valid Accuracy: 0.61
# Epoch 91, CIFAR-10 Batch 2:  Cost: 0.00481  Valid Accuracy: 0.6
# Epoch 91, CIFAR-10 Batch 3:  Cost: 0.00585  Valid Accuracy: 0.587
# Epoch 91, CIFAR-10 Batch 4:  Cost: 0.00426  Valid Accuracy: 0.605
# Epoch 91, CIFAR-10 Batch 5:  Cost: 0.00314  Valid Accuracy: 0.599
# Epoch 92, CIFAR-10 Batch 1:  Cost: 0.00176  Valid Accuracy: 0.599
# Epoch 92, CIFAR-10 Batch 2:  Cost: 0.00373  Valid Accuracy: 0.588
# Epoch 92, CIFAR-10 Batch 3:  Cost: 0.00416  Valid Accuracy: 0.582
# Epoch 92, CIFAR-10 Batch 4:  Cost: 0.00353  Valid Accuracy: 0.596
# Epoch 92, CIFAR-10 Batch 5:  Cost: 0.00257  Valid Accuracy: 0.604
# Epoch 93, CIFAR-10 Batch 1:  Cost: 0.00443  Valid Accuracy: 0.606
# Epoch 93, CIFAR-10 Batch 2:  Cost: 0.00722  Valid Accuracy: 0.596
# Epoch 93, CIFAR-10 Batch 3:  Cost: 0.00568  Valid Accuracy: 0.598
# Epoch 93, CIFAR-10 Batch 4:  Cost: 0.00358  Valid Accuracy: 0.605
# Epoch 93, CIFAR-10 Batch 5:  Cost: 0.00246  Valid Accuracy: 0.594
# Epoch 94, CIFAR-10 Batch 1:  Cost: 0.00541  Valid Accuracy: 0.604
# Epoch 94, CIFAR-10 Batch 2:  Cost: 0.00323  Valid Accuracy: 0.59
# Epoch 94, CIFAR-10 Batch 3:  Cost: 0.0039   Valid Accuracy: 0.588
# Epoch 94, CIFAR-10 Batch 4:  Cost: 0.00317  Valid Accuracy: 0.597
# Epoch 94, CIFAR-10 Batch 5:  Cost: 0.0032   Valid Accuracy: 0.597
# Epoch 95, CIFAR-10 Batch 1:  Cost: 0.00341  Valid Accuracy: 0.596
# Epoch 95, CIFAR-10 Batch 2:  Cost: 0.00337  Valid Accuracy: 0.585
# Epoch 95, CIFAR-10 Batch 3:  Cost: 0.00201  Valid Accuracy: 0.598
# Epoch 95, CIFAR-10 Batch 4:  Cost: 0.00299  Valid Accuracy: 0.606
# Epoch 95, CIFAR-10 Batch 5:  Cost: 0.0131   Valid Accuracy: 0.603
# Epoch 96, CIFAR-10 Batch 1:  Cost: 0.00533  Valid Accuracy: 0.591
# Epoch 96, CIFAR-10 Batch 2:  Cost: 0.0026   Valid Accuracy: 0.594
# Epoch 96, CIFAR-10 Batch 3:  Cost: 0.00664  Valid Accuracy: 0.591
# Epoch 96, CIFAR-10 Batch 4:  Cost: 0.00214  Valid Accuracy: 0.597
# Epoch 96, CIFAR-10 Batch 5:  Cost: 0.00409  Valid Accuracy: 0.601
# Epoch 97, CIFAR-10 Batch 1:  Cost: 0.00279  Valid Accuracy: 0.593
# Epoch 97, CIFAR-10 Batch 2:  Cost: 0.00133  Valid Accuracy: 0.597
# Epoch 97, CIFAR-10 Batch 3:  Cost: 0.00479  Valid Accuracy: 0.6
# Epoch 97, CIFAR-10 Batch 4:  Cost: 0.0039   Valid Accuracy: 0.599
# Epoch 97, CIFAR-10 Batch 5:  Cost: 0.00219  Valid Accuracy: 0.599
# Epoch 98, CIFAR-10 Batch 1:  Cost: 0.00426  Valid Accuracy: 0.582
# Epoch 98, CIFAR-10 Batch 2:  Cost: 0.00296  Valid Accuracy: 0.597
# Epoch 98, CIFAR-10 Batch 3:  Cost: 0.00899  Valid Accuracy: 0.597
# Epoch 98, CIFAR-10 Batch 4:  Cost: 0.00132  Valid Accuracy: 0.593
# Epoch 98, CIFAR-10 Batch 5:  Cost: 0.00594  Valid Accuracy: 0.598
# Epoch 99, CIFAR-10 Batch 1:  Cost: 0.00251  Valid Accuracy: 0.602
# Epoch 99, CIFAR-10 Batch 2:  Cost: 0.00184  Valid Accuracy: 0.605
# Epoch 99, CIFAR-10 Batch 3:  Cost: 0.00481  Valid Accuracy: 0.591
# Epoch 99, CIFAR-10 Batch 4:  Cost: 0.00188  Valid Accuracy: 0.594
# Epoch 99, CIFAR-10 Batch 5:  Cost: 0.00525  Valid Accuracy: 0.596
# Epoch 100, CIFAR-10 Batch 1:  Cost: 0.00409  Valid Accuracy: 0.593
# Epoch 100, CIFAR-10 Batch 2:  Cost: 0.00244  Valid Accuracy: 0.586
# Epoch 100, CIFAR-10 Batch 3:  Cost: 0.00297  Valid Accuracy: 0.6
# Epoch 100, CIFAR-10 Batch 4:  Cost: 0.00193  Valid Accuracy: 0.603
# Epoch 100, CIFAR-10 Batch 5:  Cost: 0.000974 Valid Accuracy: 0.603

# %% [markdown]
# # 检查点
#
# 模型已保存到本地。
#
# ## 测试模型
#
# 利用测试数据集测试你的模型。这将是最终的准确率。你的准确率应该高于 50%。如果没达到，请继续调整模型结构和参数。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.5913660377264023

# %% [markdown]
# ## 为何准确率只有50-80%？
#
# 你可能想问，为何准确率不能更高了？首先，对于简单的 CNN 网络来说，50% 已经不低了。纯粹猜测的准确率为10%。但是，你可能注意到有人的准确率[远远超过 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130)。这是因为我们还没有介绍所有的神经网络知识。我们还需要掌握一些其他技巧。
#
# ## 提交项目
#
# 提交项目时，确保先运行所有单元，然后再保存记事本。将 notebook 文件另存为“dlnd_image_classification.ipynb”，再在目录 "File" -> "Download as" 另存为 HTML 格式。请在提交的项目中包含 “helper.py” 和 “problem_unittests.py” 文件。
